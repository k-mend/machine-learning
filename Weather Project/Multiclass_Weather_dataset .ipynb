# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Change the project structure from rainy/cloudy etc to train/test/val

# %%
# !pip install split-folders

import splitfolders

# 1. Define where your original data is
input_folder = "/content/drive/MyDrive/Colab Notebooks/Weather Project/Multi-class Weather Dataset"

# 2. Define where you want the new split data to go
output_folder = "/content/drive/MyDrive/Colab Notebooks/Weather Project/Dataset"

# 3. Run the split
# ratio=(train, val, test) -> (80%, 10%, 10%)
splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(.8, .1, .1), group_prefix=None)

print("Success! Your data is now split into train, val, and test.")
# Out:
# Requirement already satisfied: split-folders in /usr/local/lib/python3.12/dist-packages (0.5.1)
# Copying files: 3 files [08:24, 168.30s/ files]
# Copying files: 1125 files [08:52,  2.11 files/s]
# Success! Your data is now split into train, val, and test.

# %% [markdown]
# Setting up folder

# %%
# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = '/content/drive/MyDrive/Colab Notebooks/Weather Project/Dataset'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
path = '/content/drive/MyDrive/Colab Notebooks/Weather Project/'
fullpath = f'{path}'

# %% [markdown]
# Load the dataset

# %%
# %cd {fullpath}
# Out:
# /content/drive/MyDrive/Colab Notebooks/Weather Project

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Point to the NEW folders
train_dir = './Dataset/train'
val_dir =   './Dataset/val'
test_dir =  './Dataset/test'

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

# --- Exploratory Data Analysis (EDA) ---
# This block checks your folders and displays one random image from each class

# 1. Identify the class names from the training folder automatically
try:
    class_names = sorted([d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))])
    print(f"Classes found: {class_names}")

    # 2. Setup the plot
    plt.figure(figsize=(16, 5))

    # 3. Loop through classes and plot a random image from each
    for i, class_name in enumerate(class_names):
        class_path = os.path.join(train_dir, class_name)

        # Filter for image files only (jpg, png, webp)
        images = [f for f in os.listdir(class_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.webp'))]

        if images:
            # Pick a random image
            random_image = random.choice(images)
            img_path = os.path.join(class_path, random_image)

            # Load and display
            img = mpimg.imread(img_path)
            plt.subplot(1, len(class_names), i + 1)
            plt.imshow(img)
            plt.title(f"{class_name}\n{img.shape}") # Shows class name and image size (Height, Width, Channels)
            plt.axis('off')
        else:
            print(f"No images found in folder: {class_name}")

    plt.tight_layout()
    plt.show()

except Exception as e:
    print(f"Could not run EDA. Make sure 'train_dir' is defined and points to the correct path.\nError: {e}")
# Out:
# Classes found: ['Cloudy', 'Rain', 'Shine', 'Sunrise']

# %% [markdown]
# Building the Model (Transfer Learning)
# We will use Xception as the "base" and add custom layers on top.

# %%
# 1. Setup the Data Generators
# We apply "Augmentation" to training data to prevent overfitting
train_datagen = ImageDataGenerator(
    rescale=1./255,        # Normalize pixel values
    rotation_range=30,     # Rotate images randomly
    zoom_range=0.2,        # Zoom in/out
    horizontal_flip=True,  # Flip left/right
    fill_mode='nearest'
)

# Validation and Test data should NOT be augmented, only rescaled
val_test_datagen = ImageDataGenerator(rescale=1./255)

# 2. Load the images from the folders
print("Loading Training Data:")
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(299, 299), # Xception expects 299x299
    batch_size=32,
    class_mode='categorical'
)

print("Loading Validation Data:")
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(299, 299),
    batch_size=32,
    class_mode='categorical'
)

print("Loading Test Data:")
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(299, 299),
    batch_size=32,
    class_mode='categorical',
    shuffle=False # Important for evaluation!
)
# Out:
# Loading Training Data:
# Found 899 images belonging to 4 classes.
# Loading Validation Data:
# Found 111 images belonging to 4 classes.
# Loading Test Data:
# Found 115 images belonging to 4 classes.

# %% [markdown]
# **Model Summmary**

# %%
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
import tensorflow as tf # Import tensorflow for optimizers

# 1. Load the pre-trained base model
base_model = Xception(
    weights='imagenet',       # Use patterns learned from 14M images
    include_top=False,        # Drop the top (classification) layer
    input_shape=(299, 299, 3)
)

# 2. Freeze the base model (so we don't destroy pre-trained weights)
base_model.trainable = False

# 3. Add your custom layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x) # Inner dense layer
x = Dropout(0.5)(x)                  # Regularization (drop 50% of neurons)
output = Dense(4, activation='softmax')(x) # 4 output classes (Cloudy, Rain, Shine, Sunrise)

# 4. Combine them
model = Model(inputs=base_model.input, outputs=output)

# 5. Compile
learning_rate = 0.001
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 149, 149,  │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, 149, 149,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, 149, 149,  │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 147, 147,  │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, 147, 147,  │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, 147, 147,  │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, 147, 147,  │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, 147, 147,  │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, 147, 147,  │          0 │ block2_sepconv1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, 147, 147,  │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, 147, 147,  │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 74, 74,    │      8,192 │ block1_conv2_act… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 74, 74,    │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 74, 74,    │        512 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 74, 74,    │          0 │ block2_pool[0][0… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, 74, 74,    │          0 │ add[0][0]         │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, 74, 74,    │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, 74, 74,    │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, 74, 74,    │          0 │ block3_sepconv1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, 74, 74,    │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, 74, 74,    │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 37, 37,    │     32,768 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 37, 37,    │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 37, 37,    │      1,024 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 37, 37,    │          0 │ block3_pool[0][0… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, 37, 37,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, 37, 37,    │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, 37, 37,    │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, 37, 37,    │          0 │ block4_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, 37, 37,    │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, 37, 37,    │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 19, 19,    │    186,368 │ add_1[0][0]       │
# │                     │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 19, 19,    │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      2,912 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 19, 19,    │          0 │ block4_pool[0][0… │
# │                     │ 728)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, 19, 19,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, 19, 19,    │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, 19, 19,    │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, 19, 19,    │          0 │ block5_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, 19, 19,    │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, 19, 19,    │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, 19, 19,    │          0 │ block5_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, 19, 19,    │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, 19, 19,    │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 19, 19,    │          0 │ block5_sepconv3_… │
# │                     │ 728)              │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, 19, 19,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, 19, 19,    │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, 19, 19,    │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, 19, 19,    │          0 │ block6_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, 19, 19,    │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, 19, 19,    │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, 19, 19,    │          0 │ block6_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, 19, 19,    │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, 19, 19,    │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 19, 19,    │          0 │ block6_sepconv3_… │
# │                     │ 728)              │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, 19, 19,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, 19, 19,    │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, 19, 19,    │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, 19, 19,    │          0 │ block7_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, 19, 19,    │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, 19, 19,    │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, 19, 19,    │          0 │ block7_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, 19, 19,    │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, 19, 19,    │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 19, 19,    │          0 │ block7_sepconv3_… │
# │                     │ 728)              │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, 19, 19,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, 19, 19,    │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, 19, 19,    │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, 19, 19,    │          0 │ block8_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, 19, 19,    │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, 19, 19,    │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, 19, 19,    │          0 │ block8_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, 19, 19,    │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, 19, 19,    │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 19, 19,    │          0 │ block8_sepconv3_… │
# │                     │ 728)              │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, 19, 19,    │          0 │ add_6[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, 19, 19,    │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, 19, 19,    │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, 19, 19,    │          0 │ block9_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, 19, 19,    │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, 19, 19,    │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, 19, 19,    │          0 │ block9_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, 19, 19,    │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, 19, 19,    │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 19, 19,    │          0 │ block9_sepconv3_… │
# │                     │ 728)              │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, 19, 19,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, 19, 19,    │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, 19, 19,    │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, 19, 19,    │          0 │ block10_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, 19, 19,    │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, 19, 19,    │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, 19, 19,    │          0 │ block10_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, 19, 19,    │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, 19, 19,    │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 19, 19,    │          0 │ block10_sepconv3… │
# │                     │ 728)              │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, 19, 19,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, 19, 19,    │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, 19, 19,    │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, 19, 19,    │          0 │ block11_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, 19, 19,    │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, 19, 19,    │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, 19, 19,    │          0 │ block11_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, 19, 19,    │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, 19, 19,    │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 19, 19,    │          0 │ block11_sepconv3… │
# │                     │ 728)              │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, 19, 19,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, 19, 19,    │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, 19, 19,    │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, 19, 19,    │          0 │ block12_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, 19, 19,    │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, 19, 19,    │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, 19, 19,    │          0 │ block12_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, 19, 19,    │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, 19, 19,    │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 19, 19,    │          0 │ block12_sepconv3… │
# │                     │ 728)              │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, 19, 19,    │          0 │ add_10[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, 19, 19,    │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, 19, 19,    │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, 19, 19,    │          0 │ block13_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, 19, 19,    │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, 19, 19,    │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 10, 10,    │    745,472 │ add_10[0][0]      │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, 10, 10,    │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │      4,096 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 10, 10,    │          0 │ block13_pool[0][… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, 10, 10,    │  1,582,080 │ add_11[0][0]      │
# │ (SeparableConv2D)   │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, 10, 10,    │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, 10, 10,    │          0 │ block14_sepconv1… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, 10, 10,    │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_bn │ (None, 10, 10,    │      8,192 │ block14_sepconv2… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_a… │ (None, 10, 10,    │          0 │ block14_sepconv2… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ block14_sepconv2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    524,544 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 4)         │      1,028 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,387,052 (81.59 MB)
#  Trainable params: 525,572 (2.00 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %% [markdown]
# **Train the Model**
#  We will use a "Checkpoint" to save the best version of the model automatically.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Save the best model only (if validation accuracy improves)
checkpoint = ModelCheckpoint(
    filepath='/content/drive/MyDrive/Colab Notebooks/Weather Project/best_weather_model.keras',
    save_best_only=True,
    monitor='val_accuracy',
    mode='max'
)

# Train for 10 epochs (passes through the dataset)
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator,
    callbacks=[checkpoint]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 293s 9s/step - accuracy: 0.6144 - loss: 0.9293 - val_accuracy: 0.8829 - val_loss: 0.3446
# Epoch 2/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8765 - loss: 0.3381 - val_accuracy: 0.9099 - val_loss: 0.2701
# Epoch 3/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.8857 - loss: 0.2904 - val_accuracy: 0.8829 - val_loss: 0.2677
# Epoch 4/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9124 - loss: 0.2382 - val_accuracy: 0.9459 - val_loss: 0.2310
# Epoch 5/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9056 - loss: 0.2159 - val_accuracy: 0.9189 - val_loss: 0.2192
# Epoch 6/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9288 - loss: 0.1663 - val_accuracy: 0.9459 - val_loss: 0.2394
# Epoch 7/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9384 - loss: 0.1745 - val_accuracy: 0.9099 - val_loss: 0.2298
# Epoch 8/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9415 - loss: 0.1592 - val_accuracy: 0.9459 - val_loss: 0.2378
# Epoch 9/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9518 - loss: 0.1499 - val_accuracy: 0.9369 - val_loss: 0.2220
# Epoch 10/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9495 - loss: 0.1366 - val_accuracy: 0.9369 - val_loss: 0.2251

# %% [markdown]
# **Visualize Results**
# To see a graph of how your model improved over time.

# %%
import matplotlib.pyplot as plt

# Extract results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Plot Accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.legend()

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# **Testing** on images the model has never seen before

# %%
print("Evaluating on Test Set...")
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Evaluating on Test Set...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 46s 15s/step - accuracy: 0.9204 - loss: 0.2881
# Test Accuracy: 93.91%

# %% [markdown]
# **TESTING ON RANDOM IMAGE FROM THE INTERNET**

# %%
from tensorflow.keras.preprocessing.image import load_img

# %%
X = load_img("./Dataset/rainy-weather-and-raindrops-on-the-glass.webp")

# %%
import numpy as np

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model # Import load_model

# Path to an image you want to test (upload one to Colab files first)
img_path = "./Dataset/rainy-weather-and-raindrops-on-the-glass.webp"

# Load the best trained model (ensure this path matches where ModelCheckpoint saved it)
model_path = 'best_weather_model.keras'
model = load_model(model_path)

img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = x / 255.0

predictions = model.predict(x)
class_labels = list(train_generator.class_indices.keys())
print(f"Predicted Class: {class_labels[np.argmax(predictions)]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 19s 19s/step
# Predicted Class: Rain

# %% [markdown]
# **CONVERT THE MODEL TO A LIGHTER VERSION IE TENSORFLOW LITE THAT CAN EASILY BELOADED TO AWS LAMBDA.**

# %%
import tensorflow as tf

# 1. Load your trained model
model = tf.keras.models.load_model('best_weather_model.keras')

# 2. Initialize the Converter
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 3. Convert the model
tflite_model = converter.convert()

# 4. Save the TFLite file
with open('weather_model.tflite', 'wb') as f_out:
    f_out.write(tflite_model)

print("Success! Download 'weather_model.tflite' from the files tab.")
# Out:
# Saved artifact at '/tmp/tmp2fzxn2oz'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   133784211739408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191999376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191999568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192000528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191998608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192001680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191999184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191998992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191999760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191995536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191997840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191995920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191992656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191998224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191994768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191996112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191998416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191999952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192001296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192000144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192001488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191998032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192000720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191995152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191995344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192000336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192002640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192002064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192003024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192003216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192003408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784191998800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192003792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192003600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192004176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192004752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192004368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192004560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192002832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192004944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192002256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192002448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192001104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192005904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192005328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192006288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192006480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192006672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192001872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192007056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192006864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192007440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192003984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192007632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192007248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192005712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192005136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192008016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192005520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192007824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133784192006096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533879568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533879760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533880912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533881104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533879376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533881488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533881296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533881872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533882064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533882256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533880336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533882640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533882448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533883024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533883216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533883408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533881680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533883792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533883600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533884176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533884368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533884560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533882832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533884944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533884752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533885328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533885520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533885712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533883984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533886096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533885904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533886480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533886672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533886864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533885136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533887248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533887056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533887632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533887824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533888016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533886288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533888400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533888208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533888784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533888976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533889168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533887440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533889552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533889360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533889936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533890128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533890320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533888592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533890704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533890512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533891088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533891280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533891472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533889744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533891856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533891664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533892240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533892432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533892624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533890896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533893008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533892816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533893392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533893584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533893776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533892048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533894160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533893968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533894544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533894736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533894928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533893200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533895312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533895120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533880144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533880720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533894352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533895504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533880528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533879952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534649616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534650768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534650960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534650192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534651344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534651152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534651728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534651920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534652112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534649424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534652496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534652304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534652880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534653072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534653264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534651536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534653648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534653456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534654032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534654224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534654416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534652688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534654800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534654608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534655184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534655376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534655568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534653840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534655952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534655760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534656336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534656528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534656720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534654992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534657104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534656912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534657488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534657680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534657872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534656144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534658256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534658064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534658640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534658832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534659024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534657296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534659408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534659216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534659792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534659984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534660176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534658448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534660560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534660368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534660944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534661136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534661328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534659600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534661712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534661520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534662096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534662288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534662480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534660752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534662864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534662672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534663248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534663824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534663440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534663632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534661904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534664016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534650576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534650384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534650000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534664976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534664400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534665360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534663056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534665552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534664784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534665168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534664592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534649808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533339664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533339856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783534664208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533340240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533340048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533339472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533339088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133783533339280: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Success! Download 'weather_model.tflite' from the files tab.
