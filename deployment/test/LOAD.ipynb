# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
with open('model_C=1.0.bin', 'rb') as f_in:
    dv,model = pickle.load(f_in)
# Out:
# /home/mendyk/.local/share/virtualenvs/module5-go20E7LY/lib/python3.12/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator DictVectorizer from version 1.5.1 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mendyk/.local/share/virtualenvs/module5-go20E7LY/lib/python3.12/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.5.1 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
test_dicts ={"customerid":"9420-lojkx","gender":"female","seniorcitizen":0,"partner":"no","dependents":"no","tenure":15,"phoneservice":"yes","multiplelines":"no","internetservice":"fiber_optic","onlinesecurity":"yes","onlinebackup":"yes","deviceprotection":"no","techsupport":"no","streamingtv":"yes","streamingmovies":"yes","contract":"month-to-month","paperlessbilling":"yes","paymentmethod":"credit_card_(automatic)","monthlycharges":99.1,"totalcharges":"1426.4","churn":1}

# %%
x_test = dv.transform(test_dicts)

# %%
model.predict_proba(x_test)[:,1]
# Out:
# array([0.68436876])

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /home/mendyk/.local/share/virtualenvs/module5-go20E7LY/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mendyk/.local/share/virtualenvs/module5-go20E7LY/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mendyk/.local/share/virtualenvs/module5-go20E7LY/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mendyk/.local/share/virtualenvs/module5-go20E7LY/lib/python3.12/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mendyk/.local/share/virtualenvs/module5-go20E7LY/lib/python3.12/site-packages (from requests) (2025.10.5)

# %% [markdown]
# LET US SEND A REQUEST TO THE SERVER VIA THIS NOTEBOOK

# %%
import requests #plural. requests is a third party library used to send http requests to a web service

url ='http://0.0.0.0:9696/predict'

# customer_id ='xyz-123'
customer = test_dicts
response = requests.post(url, json=customer).json()
print(response)

if response['churn']==(True):
    print('sending promo email to %s' % customer_id)
else:
    print('not sending promo email to %s' % customer_id)
# Out:
# {'churn': True, 'churn_prediction': 0.6843687647688343}
# sending promo email to xyz-123
